# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Food_Delivery_Route_Efficiency_Dataset.csv")

# %%
df.head()
# Out:
#    order_id  distance_km  delivery_time_min traffic_level  route_length_km  \
# 0         1         7.97               63.8          High             9.75
# 1         2         0.90                7.6          High             1.28
# 2         3        11.12               78.0        Medium            16.65
# 3         4         4.90               24.8           Low             5.25
# 4         5        10.04               56.0          High            11.34
#
#   delivery_mode weather        order_time restaurant_zone customer_zone
# 0       Bicycle   Clear  2025-01-01 15:29           South         North
# 1           Car  Cloudy  2025-01-03 00:47            West         North
# 2          Bike   Rainy  2025-01-04 17:32           South       Central
# 3       Scooter   Rainy  2025-01-01 14:12         Central       Central
# 4           Car   Rainy  2025-01-02 16:50            West         North

# %%
df.describe()
# Out:
#          order_id  distance_km  delivery_time_min  route_length_km
# count  200.000000   200.000000         200.000000       200.000000
# mean   100.500000     6.624750          44.744500         8.155850
# std     57.879185     3.371918          25.083925         4.303207
# min      1.000000     0.530000           2.400000         0.580000
# 25%     50.750000     3.687500          23.725000         4.420000
# 50%    100.500000     6.845000          44.650000         8.520000
# 75%    150.250000     9.797500          63.900000        11.800000
# max    200.000000    12.000000         108.800000        17.290000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_id           200 non-null    int64
#  1   distance_km        200 non-null    float64
#  2   delivery_time_min  200 non-null    float64
#  3   traffic_level      200 non-null    object
#  4   route_length_km    200 non-null    float64
#  5   delivery_mode      200 non-null    object
#  6   weather            200 non-null    object
#  7   order_time         200 non-null    object
#  8   restaurant_zone    200 non-null    object
#  9   customer_zone      200 non-null    object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 15.8+ KB

# %% [markdown]
# **feature engineering**

# %%
# We're converting the traffic_level column into an ordinal categorical variable.
# The order here is: Low < Medium < High.

traffic_mapping = {
    'Low': 0,
    'Medium': 1,
    'High': 2
}

df['traffic_level_encoded'] = df['traffic_level'].map(traffic_mapping)

# Drop the original column
df = df.drop('traffic_level', axis=1)
df
# Out:
#      order_id  distance_km  delivery_time_min  route_length_km delivery_mode  \
# 0           1         7.97               63.8             9.75       Bicycle
# 1           2         0.90                7.6             1.28           Car
# 2           3        11.12               78.0            16.65          Bike
# 3           4         4.90               24.8             5.25       Scooter
# 4           5        10.04               56.0            11.34           Car
# ..        ...          ...                ...              ...           ...
# 195       196         9.02               38.4             9.57          Bike
# 196       197         6.73               59.2            10.04          Bike
# 197       198         6.98               51.4             7.83       Scooter
# 198       199         3.80               29.2             5.34       Bicycle
# 199       200         6.55               40.8             7.72           Car
#
#     weather        order_time restaurant_zone customer_zone  \
# 0     Clear  2025-01-01 15:29           South         North
# 1    Cloudy  2025-01-03 00:47            West         North
# 2     Rainy  2025-01-04 17:32           South       Central
# 3     Rainy  2025-01-01 14:12         Central       Central
# 4     Rainy  2025-01-02 16:50            West         North
# ..      ...               ...             ...           ...
# 195  Cloudy  2025-01-03 09:22         Central         South
# 196  Cloudy  2025-01-03 03:32           South         South
# 197  Cloudy  2025-01-01 08:03         Central          West
# 198   Rainy  2025-01-04 07:34           South         North
# 199   Windy  2025-01-04 15:12           South         North
#
#      traffic_level_encoded
# 0                        2
# 1                        2
# 2                        1
# 3                        0
# 4                        2
# ..                     ...
# 195                      0
# 196                      0
# 197                      2
# 198                      1
# 199                      1
#
# [200 rows x 10 columns]

# %%
# one-hot encoding for delivery_mode
delivery_dummies = pd.get_dummies(df['delivery_mode'], prefix='delivery_mode')

# Merge with original df
df = pd.concat([df, delivery_dummies], axis=1)

# We can delete the original delivery_mode column
df.drop(columns=['delivery_mode'], inplace=True)
df
# Out:
#      order_id  distance_km  delivery_time_min  route_length_km weather  \
# 0           1         7.97               63.8             9.75   Clear
# 1           2         0.90                7.6             1.28  Cloudy
# 2           3        11.12               78.0            16.65   Rainy
# 3           4         4.90               24.8             5.25   Rainy
# 4           5        10.04               56.0            11.34   Rainy
# ..        ...          ...                ...              ...     ...
# 195       196         9.02               38.4             9.57  Cloudy
# 196       197         6.73               59.2            10.04  Cloudy
# 197       198         6.98               51.4             7.83  Cloudy
# 198       199         3.80               29.2             5.34   Rainy
# 199       200         6.55               40.8             7.72   Windy
#
#            order_time restaurant_zone customer_zone  traffic_level_encoded  \
# 0    2025-01-01 15:29           South         North                      2
# 1    2025-01-03 00:47            West         North                      2
# 2    2025-01-04 17:32           South       Central                      1
# 3    2025-01-01 14:12         Central       Central                      0
# 4    2025-01-02 16:50            West         North                      2
# ..                ...             ...           ...                    ...
# 195  2025-01-03 09:22         Central         South                      0
# 196  2025-01-03 03:32           South         South                      0
# 197  2025-01-01 08:03         Central          West                      2
# 198  2025-01-04 07:34           South         North                      1
# 199  2025-01-04 15:12           South         North                      1
#
#      delivery_mode_Bicycle  delivery_mode_Bike  delivery_mode_Car  \
# 0                     True               False              False
# 1                    False               False               True
# 2                    False                True              False
# 3                    False               False              False
# 4                    False               False               True
# ..                     ...                 ...                ...
# 195                  False                True              False
# 196                  False                True              False
# 197                  False               False              False
# 198                   True               False              False
# 199                  False               False               True
#
#      delivery_mode_Scooter
# 0                    False
# 1                    False
# 2                    False
# 3                     True
# 4                    False
# ..                     ...
# 195                  False
# 196                  False
# 197                   True
# 198                  False
# 199                  False
#
# [200 rows x 13 columns]

# %%
df['weather'].unique()
# Out:
# array(['Clear', 'Cloudy', 'Rainy', 'Windy'], dtype=object)

# %%
# one-hot encoding for weather
weather_dummies = pd.get_dummies(df['weather'], prefix='weather')

# Merge with original df
df = pd.concat([df, weather_dummies], axis=1)

# We can delete the original weather column
df.drop(columns=['weather'], inplace=True)
df
# Out:
#      order_id  distance_km  delivery_time_min  route_length_km  \
# 0           1         7.97               63.8             9.75
# 1           2         0.90                7.6             1.28
# 2           3        11.12               78.0            16.65
# 3           4         4.90               24.8             5.25
# 4           5        10.04               56.0            11.34
# ..        ...          ...                ...              ...
# 195       196         9.02               38.4             9.57
# 196       197         6.73               59.2            10.04
# 197       198         6.98               51.4             7.83
# 198       199         3.80               29.2             5.34
# 199       200         6.55               40.8             7.72
#
#            order_time restaurant_zone customer_zone  traffic_level_encoded  \
# 0    2025-01-01 15:29           South         North                      2
# 1    2025-01-03 00:47            West         North                      2
# 2    2025-01-04 17:32           South       Central                      1
# 3    2025-01-01 14:12         Central       Central                      0
# 4    2025-01-02 16:50            West         North                      2
# ..                ...             ...           ...                    ...
# 195  2025-01-03 09:22         Central         South                      0
# 196  2025-01-03 03:32           South         South                      0
# 197  2025-01-01 08:03         Central          West                      2
# 198  2025-01-04 07:34           South         North                      1
# 199  2025-01-04 15:12           South         North                      1
#
#      delivery_mode_Bicycle  delivery_mode_Bike  delivery_mode_Car  \
# 0                     True               False              False
# 1                    False               False               True
# 2                    False                True              False
# 3                    False               False              False
# 4                    False               False               True
# ..                     ...                 ...                ...
# 195                  False                True              False
# 196                  False                True              False
# 197                  False               False              False
# 198                   True               False              False
# 199                  False               False               True
#
#      delivery_mode_Scooter  weather_Clear  weather_Cloudy  weather_Rainy  \
# 0                    False           True           False          False
# 1                    False          False            True          False
# 2                    False          False           False           True
# 3                     True          False           False           True
# 4                    False          False           False           True
# ..                     ...            ...             ...            ...
# 195                  False          False            True          False
# 196                  False          False            True          False
# 197                   True          False            True          False
# 198                  False          False           False           True
# 199                  False          False           False          False
#
#      weather_Windy
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ..             ...
# 195          False
# 196          False
# 197          False
# 198          False
# 199           True
#
# [200 rows x 16 columns]

# %%
# convert to order_time column from string to a datetime
df['order_time'] = pd.to_datetime(df['order_time'])

# %%
# Month
df['order_month'] = df['order_time'].dt.month

# Day (day of the month)
df['order_day'] = df['order_time'].dt.day

# Hour
df['order_hour'] = df['order_time'].dt.hour

# Minute
df['order_minute'] = df['order_time'].dt.minute
df
# Out:
#      order_id  distance_km  delivery_time_min  route_length_km  \
# 0           1         7.97               63.8             9.75
# 1           2         0.90                7.6             1.28
# 2           3        11.12               78.0            16.65
# 3           4         4.90               24.8             5.25
# 4           5        10.04               56.0            11.34
# ..        ...          ...                ...              ...
# 195       196         9.02               38.4             9.57
# 196       197         6.73               59.2            10.04
# 197       198         6.98               51.4             7.83
# 198       199         3.80               29.2             5.34
# 199       200         6.55               40.8             7.72
#
#              order_time restaurant_zone customer_zone  traffic_level_encoded  \
# 0   2025-01-01 15:29:00           South         North                      2
# 1   2025-01-03 00:47:00            West         North                      2
# 2   2025-01-04 17:32:00           South       Central                      1
# 3   2025-01-01 14:12:00         Central       Central                      0
# 4   2025-01-02 16:50:00            West         North                      2
# ..                  ...             ...           ...                    ...
# 195 2025-01-03 09:22:00         Central         South                      0
# 196 2025-01-03 03:32:00           South         South                      0
# 197 2025-01-01 08:03:00         Central          West                      2
# 198 2025-01-04 07:34:00           South         North                      1
# 199 2025-01-04 15:12:00           South         North                      1
#
#      delivery_mode_Bicycle  delivery_mode_Bike  delivery_mode_Car  \
# 0                     True               False              False
# 1                    False               False               True
# 2                    False                True              False
# 3                    False               False              False
# 4                    False               False               True
# ..                     ...                 ...                ...
# 195                  False                True              False
# 196                  False                True              False
# 197                  False               False              False
# 198                   True               False              False
# 199                  False               False               True
#
#      delivery_mode_Scooter  weather_Clear  weather_Cloudy  weather_Rainy  \
# 0                    False           True           False          False
# 1                    False          False            True          False
# 2                    False          False           False           True
# 3                     True          False           False           True
# 4                    False          False           False           True
# ..                     ...            ...             ...            ...
# 195                  False          False            True          False
# 196                  False          False            True          False
# 197                   True          False            True          False
# 198                  False          False           False           True
# 199                  False          False           False          False
#
#      weather_Windy  order_month  order_day  order_hour  order_minute
# 0            False            1          1          15            29
# 1            False            1          3           0            47
# 2            False            1          4          17            32
# 3            False            1          1          14            12
# 4            False            1          2          16            50
# ..             ...          ...        ...         ...           ...
# 195          False            1          3           9            22
# 196          False            1          3           3            32
# 197          False            1          1           8             3
# 198          False            1          4           7            34
# 199           True            1          4          15            12
#
# [200 rows x 20 columns]

# %%
# We can delete unnecessary columns for our model

df.drop(columns=['order_id', 'order_time', 'customer_zone', 'restaurant_zone'], inplace=True)
df
# Out:
#      distance_km  delivery_time_min  route_length_km  traffic_level_encoded  \
# 0           7.97               63.8             9.75                      2
# 1           0.90                7.6             1.28                      2
# 2          11.12               78.0            16.65                      1
# 3           4.90               24.8             5.25                      0
# 4          10.04               56.0            11.34                      2
# ..           ...                ...              ...                    ...
# 195         9.02               38.4             9.57                      0
# 196         6.73               59.2            10.04                      0
# 197         6.98               51.4             7.83                      2
# 198         3.80               29.2             5.34                      1
# 199         6.55               40.8             7.72                      1
#
#      delivery_mode_Bicycle  delivery_mode_Bike  delivery_mode_Car  \
# 0                     True               False              False
# 1                    False               False               True
# 2                    False                True              False
# 3                    False               False              False
# 4                    False               False               True
# ..                     ...                 ...                ...
# 195                  False                True              False
# 196                  False                True              False
# 197                  False               False              False
# 198                   True               False              False
# 199                  False               False               True
#
#      delivery_mode_Scooter  weather_Clear  weather_Cloudy  weather_Rainy  \
# 0                    False           True           False          False
# 1                    False          False            True          False
# 2                    False          False           False           True
# 3                     True          False           False           True
# 4                    False          False           False           True
# ..                     ...            ...             ...            ...
# 195                  False          False            True          False
# 196                  False          False            True          False
# 197                   True          False            True          False
# 198                  False          False           False           True
# 199                  False          False           False          False
#
#      weather_Windy  order_month  order_day  order_hour  order_minute
# 0            False            1          1          15            29
# 1            False            1          3           0            47
# 2            False            1          4          17            32
# 3            False            1          1          14            12
# 4            False            1          2          16            50
# ..             ...          ...        ...         ...           ...
# 195          False            1          3           9            22
# 196          False            1          3           3            32
# 197          False            1          1           8             3
# 198          False            1          4           7            34
# 199           True            1          4          15            12
#
# [200 rows x 16 columns]

# %% [markdown]
# ***feature engineering finished**

# %% [markdown]
# **LİNEAR REGRESSİON MODEL**

# %%
##independent and dependent features

X = df.drop(columns=['delivery_time_min'])
y = df['delivery_time_min']

# %%
# train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=15)

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## prediction
y_pred=regression.predict(X_test)

# %%
## Performance Metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print("mse: ", mse)
print("mae: ", mae)
print("rmse: ", rmse)
# Out:
# mse:  72.75819971709167
# mae:  6.412957709641237
# rmse:  8.529841717001064

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print("r2 score: ", score)
#adjusted R-squared
print(1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
# Out:
# r2 score:  0.8919800217049342
# 0.8443241489276992

# %% [markdown]
# **SUMMARY**

# %% [markdown]
# The model’s predictions have an average error of 6–8.5 minutes, which is an acceptable range for most delivery applications.

# %% [markdown]
# R² indicates how much of the variability in the target variable the model explains.
#
# 0 → the model explains nothing
#
# 1 → perfect explanation
#
# In this case, the model explains 89% of the variability in delivery times.
